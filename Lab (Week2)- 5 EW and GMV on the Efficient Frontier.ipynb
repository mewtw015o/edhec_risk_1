# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import pandas as pd
import edhec_risk_kit as erk

ind = erk.get_ind_returns()
er = erk.annualized_rets(ind["1996":"2000"],12)
cov = ind["1996":"2000"].cov()

# %%
l = ["Food","Steel"]
erk.msr(0.1,er[l],cov.loc[l,l]) #weights
# Out:
# array([0.75040363, 0.24959637])

# %%
er[l] #Expected Return
# Out:
# Food     0.116799
# Steel    0.115809
# dtype: float64

# %%
erk.msr(0.1,np.array([.11,.12]),cov.loc[l,l]) 
#guessing and using different expected return to estimate the weights
#Notice the big changes in weights, relative to small changes in inputs of returns
# Out:
# array([0.57930354, 0.42069646])

# %%
erk.msr(0.1,np.array([.10,.13]),cov.loc[l,l]) 
#guessing and using different expected return to estimate the weights
#Notice the big changes in weights, relative to small changes in inputs of returns
# Out:
# array([0., 1.])

# %%
erk.msr(0.1,np.array([.13,.10]),cov.loc[l,l]) 
#guessing and using different expected return to estimate the weights
#Notice the big changes in weights, relative to small changes in inputs of returns
# Out:
# array([1., 0.])

# %%
erk.plot_ef(20,er,cov,show_cml=True,riskfree_rate=0.1)
# Out:
# .-
# <AxesSubplot:xlabel='Volatility'>

# %% [markdown]
# # EW Portfolio

# %%
erk.plot_ef(20,er,cov,show_cml=True,riskfree_rate=0.1,show_ew=True) #equally weighted portfolio
# Out:
# .-
# <AxesSubplot:xlabel='Volatility'>

# %% [markdown]
# # GMV Portfolio

# %%
erk.plot_ef(20,er,cov,show_cml=True,riskfree_rate=0.1,show_ew=True, show_gmv=True)
# Out:
# .-
# <AxesSubplot:xlabel='Volatility'>
